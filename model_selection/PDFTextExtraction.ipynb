# %%
pip install pdfminer.six PyMuPDF pdfplumber pytesseract pdf2image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 31.5 MB/s eta 0:00:00
# ...

# %%
# Required Libraries
import os  # For file system operations
from pdfminer.high_level import extract_text  # For PDF extraction with pdfminer.six
import fitz  # PyMuPDF (for PDF extraction)
import pdfplumber  # For PDF extraction with pdfplumber
import pytesseract  # For OCR with Tesseract
from pdf2image import convert_from_path  # To convert PDF pages to images for Tesseract OCR

# %%
from pdfminer.high_level import extract_text

def extract_text_pdfminer(pdf_path):
    """Extract text from PDF using pdfminer.six."""
    try:
        text = extract_text(pdf_path)
        return text
    except Exception as e:
        print(f"Error using pdfminer on {pdf_path}: {e}")
        return None

# Example usage
# text_pdfminer = extract_text_pdfminer(r"C:\Users\acer\Desktop\Task_pdfs\250883_english_01042024.pdf")
# print(text_pdfminer[500:2000])  # Print the first 100 characters of the extracted text

# %%
import fitz  # PyMuPDF

def extract_text_pymupdf(pdf_path):
    """Extract text from PDF using PyMuPDF (fitz)."""
    try:
        doc = fitz.open(pdf_path)
        text = ""
        for page in doc:
            text += page.get_text()
        return text
    except Exception as e:
        print(f"Error using PyMuPDF on {pdf_path}: {e}")
        return None

# Example usage
# text_pymupdf = extract_text_pymupdf(r"C:\Users\acer\Desktop\Task_pdfs\250883_english_01042024.pdf")
# print(text_pymupdf[:2000])  # Print the first 100 characters of the extracted text

# %%
import pdfplumber

def extract_text_pdfplumber(pdf_path):
    """Extract text from PDF using pdfplumber."""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text = ""
            for page in pdf.pages:
                text += page.extract_text()
        return text
    except Exception as e:
        print(f"Error using pdfplumber on {pdf_path}: {e}")
        return None

# Example usage
# text_pdfplumber = extract_text_pdfplumber(r"C:\Users\acer\Desktop\Task_pdfs\250883_english_01042024.pdf")
# print(text_pdfplumber[:2000])  # Print the first 100 characters of the extracted text

# %%
import pytesseract
from pdf2image import convert_from_path


# Set path to Tesseract executable if necessary (only for Windows users)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Update to your Tesseract path if needed

def extract_text_tesseract(pdf_path):
    """Extract text from a PDF using Tesseract OCR."""
    try:
        # Convert PDF pages to images
        images = convert_from_path(pdf_path)
        text = ""
        for image in images:
            # Use Tesseract to perform OCR on the image
            text += pytesseract.image_to_string(image)
        if not text.strip():  # Check if any text was extracted
            print(f"No text extracted from {pdf_path} using Tesseract.")
            return None
        return text
    except Exception as e:
        print(f"Error using Tesseract OCR on {pdf_path}: {e}")
        return None

# Example usage
# pdf_path = r"C:\Users\acer\Desktop\Task_pdfs\250883_english_01042024.pdf"
# text_tesseract = extract_text_tesseract(pdf_path)

# # Check if text is extracted successfully
# if text_tesseract is not None:
#     print(text_tesseract[:2000])  # Print the first 2000 characters of the extracted text
# else:
#     print("No text extracted using Tesseract OCR.")

# %%
def extract_text_easyocr(pdf_path):
    try:
        images = convert_from_path(pdf_path)
        text = ""
        for image in images:
            # Use EasyOCR to perform OCR on the image
            result = ocr_easy.readtext(image)
            for (bbox, word, prob) in result:
                text += word + " "  # Extract the text
        return text
    except Exception as e:
        print(f"Error using EasyOCR on {pdf_path}: {e}")
        return None

# %%
def extract_first_n_characters(methods, pdf_path, n=100):
    """Extract the first n characters from each extraction method."""
    results = {}

    for name, method in methods.items():
        text = method(pdf_path)
        if text:
            # Get the first n characters
            results[name] = text[:n]
        else:
            results[name] = "No text extracted."

    return results


# Define methods dictionary
methods = {
    "pdfminer": extract_text_pdfminer,
    ch
    "pdfplumber": extract_text_pdfplumber,
    "Tesseract": extract_text_tesseract,
    #"PaddleOCR": extract_text_with_paddleocr,
    "EasyOCR": extract_text_easyocr,
}

# Example usage


# pdf_path = "/content/pdf3.pdf" # Update to your actual PDF path
# results = extract_first_n_characters(methods, pdf_path, n=100)

#     # Print results
# for method, text in results.items():
#     print(f"--- {method} ---")
#     print()
#     print(text)
#     print()
#     print()


for i in range(1,19):


    print(f'pdf number = {i}')
    pdf_path = "/content/pdf{i}.pdf".format(i = i)  # Update to your actual PDF path
    results = extract_first_n_characters(methods, pdf_path, n=2000)

    print()
    # Print results
    for method, text in results.items():
        print(f"--- {method} ---")
        print()
        print(text)
        print()
        print()
# Out:
# pdf number = 1
# Error using Tesseract OCR on /content/pdf1.pdf: Unable to get page count. Is poppler installed and in PATH?
# Error using EasyOCR on /content/pdf1.pdf: Unable to get page count. Is poppler installed and in PATH?
#
# --- pdfminer ---
#
# ...
